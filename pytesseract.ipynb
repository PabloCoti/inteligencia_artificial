# %%
# Ubicación teseract
# C:\Program Files\Tesseract-OCR
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\pca20\documents\github\inteligencia_artificial\.venv\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\pca20\documents\github\inteligencia_artificial\.venv\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\pca20\documents\github\inteligencia_artificial\.venv\lib\site-packages (from pytesseract) (10.2.0)

# %%
# Cargar paquetes
import cv2
import pytesseract
import matplotlib.pyplot as plt

# para uso en windows
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
placa = []
image = cv2.imread('./storage/image/auto.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(gray, cmap='gray')

# %%
gray = cv2.blur(gray, (3,3))
plt.imshow(gray, cmap='gray')

# %%
canny = cv2.Canny(gray, 130, 200)
plt.imshow(canny, cmap='gray')

# %%
dilate = cv2.dilate(canny, None, iterations=1)
plt.imshow(dilate, cmap='gray')
