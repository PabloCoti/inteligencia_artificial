# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Para medir el rendimiento del carro en millas por galon segun su potencia y su peso
auto = sns.load_dataset('mpg')
auto.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# calculo de correlacion sobre las variables
correlacion = auto.corr(numeric_only = True)

# %%
# estilizar correlacion
correlacion.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_73d2c_row0_col0, #T_73d2c_row1_col1, #T_73d2c_row2_col2, #T_73d2c_row3_col3, #T_73d2c_row4_col4, #T_73d2c_row5_col5, #T_73d2c_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_73d2c_row0_col1, #T_73d2c_row0_col2, #T_73d2c_row0_col3, #T_73d2c_row0_col4, #T_73d2c_row3_col5, #T_73d2c_row3_col6, #T_73d2c_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_73d2c_row0_col5 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_73d2c_row0_col6 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_73d2c_row1_col0, #T_73d2c_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_73d2c_row1_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_73d2c_row1_col3, #T_73d2c_row3_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_73d2c_row1_col4, #T_73d2c_row2_col3, #T_73d2c_row3_col2, #T_73d2c_row4_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_73d2c_row1_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_73d2c_row1_col6, #T_73d2c_row5_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_73d2c_row2_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_73d2c_row2_col1 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_73d2c_row2_col4, #T_73d2c_row4_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_73d2c_row2_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_73d2c_row2_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_73d2c_row3_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_73d2c_row4_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_73d2c_row4_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_73d2c_row4_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_73d2c_row5_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_73d2c_row5_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_73d2c_row5_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_73d2c_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_73d2c_row5_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_73d2c_row6_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_73d2c_row6_col1, #T_73d2c_row6_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_73d2c_row6_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_73d2c_row6_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_73d2c_row6_col5 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# </style>
# <table id="T_73d2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73d2c_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_73d2c_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_73d2c_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_73d2c_level0_col3" class="col_heading level0 col3" >horsepower</th>
#       <th id="T_73d2c_level0_col4" class="col_heading level0 col4" >weight</th>
#       <th id="T_73d2c_level0_col5" class="col_heading level0 col5" >acceleration</th>
#       <th id="T_73d2c_level0_col6" class="col_heading level0 col6" >model_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73d2c_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_73d2c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_73d2c_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_73d2c_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_73d2c_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_73d2c_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_73d2c_row0_col5" class="data row0 col5" >0.420289</td>
#       <td id="T_73d2c_row0_col6" class="data row0 col6" >0.579267</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_73d2c_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_73d2c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_73d2c_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_73d2c_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_73d2c_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_73d2c_row1_col5" class="data row1 col5" >-0.505419</td>
#       <td id="T_73d2c_row1_col6" class="data row1 col6" >-0.348746</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_73d2c_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_73d2c_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_73d2c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_73d2c_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_73d2c_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_73d2c_row2_col5" class="data row2 col5" >-0.543684</td>
#       <td id="T_73d2c_row2_col6" class="data row2 col6" >-0.370164</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row3" class="row_heading level0 row3" >horsepower</th>
#       <td id="T_73d2c_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_73d2c_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_73d2c_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_73d2c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_73d2c_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_73d2c_row3_col5" class="data row3 col5" >-0.689196</td>
#       <td id="T_73d2c_row3_col6" class="data row3 col6" >-0.416361</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row4" class="row_heading level0 row4" >weight</th>
#       <td id="T_73d2c_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_73d2c_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_73d2c_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_73d2c_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_73d2c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_73d2c_row4_col5" class="data row4 col5" >-0.417457</td>
#       <td id="T_73d2c_row4_col6" class="data row4 col6" >-0.306564</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row5" class="row_heading level0 row5" >acceleration</th>
#       <td id="T_73d2c_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_73d2c_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_73d2c_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_73d2c_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_73d2c_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_73d2c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_73d2c_row5_col6" class="data row5 col6" >0.288137</td>
#     </tr>
#     <tr>
#       <th id="T_73d2c_level0_row6" class="row_heading level0 row6" >model_year</th>
#       <td id="T_73d2c_row6_col0" class="data row6 col0" >0.579267</td>
#       <td id="T_73d2c_row6_col1" class="data row6 col1" >-0.348746</td>
#       <td id="T_73d2c_row6_col2" class="data row6 col2" >-0.370164</td>
#       <td id="T_73d2c_row6_col3" class="data row6 col3" >-0.416361</td>
#       <td id="T_73d2c_row6_col4" class="data row6 col4" >-0.306564</td>
#       <td id="T_73d2c_row6_col5" class="data row6 col5" >0.288137</td>
#       <td id="T_73d2c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = auto['weight']
x = sm.add_constant(x)
y = auto['mpg']

# %%
resultado = sm.OLS(y, x).fit()
resultado.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     888.9
# Date:                Wed, 07 Feb 2024   Prob (F-statistic):          2.97e-103
# Time:                        09:03:40   Log-Likelihood:                -1148.4
# No. Observations:                 398   AIC:                             2301.
# Df Residuals:                     396   BIC:                             2309.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.3174      0.795     58.243      0.000      44.754      47.881
# weight        -0.0077      0.000    -29.814      0.000      -0.008      -0.007
# ==============================================================================
# Omnibus:                       40.423   Durbin-Watson:                   0.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.695
# Skew:                           0.713   Prob(JB):                     4.89e-13
# Kurtosis:                       4.176   Cond. No.                     1.13e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ax1 = sns.regplot(data = auto, x = 'weight', y = 'mpg')
ax1.set_xlabel('Peso')
ax1.set_ylabel('Millas por galon (mpg)')
ax1.set_title('Relacin peso-mpg')
ax1.plot();

# %%
fig2, ax2 = plt.subplots(figsize=(5,3))
sns.boxplot(x = 'origin', y = 'mpg', data = auto)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
archivo = './RACE.csv'
ferrari = pd.read_csv(archivo)

# %%
# Imprimir valores de ferrari
ferrari
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-02-06  260.399994  263.010010  258.959991  261.309998  259.440613
# 1    2023-02-07  262.510010  267.250000  262.278015  266.910004  265.000549
# 2    2023-02-08  266.459991  267.839996  265.149994  266.559998  264.653046
# 3    2023-02-09  269.579987  270.119995  265.070007  266.309998  264.404846
# 4    2023-02-10  258.299988  260.130005  256.920013  259.679993  257.822266
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-01-30  348.000000  350.299988  347.290009  349.410004  349.410004
# 247  2024-01-31  353.109985  354.684998  345.920013  345.920013  345.920013
# 248  2024-02-01  372.779999  391.420013  372.690002  389.450012  389.450012
# 249  2024-02-02  379.869995  380.399994  371.500000  379.250000  379.250000
# 250  2024-02-05  370.920013  374.640015  369.060089  370.410004  370.410004
#
#       Volume
# 0     395300
# 1     464800
# 2     445200
# 3     306600
# 4     564700
# ..       ...
# 246   382300
# 247   386400
# 248  1609900
# 249   694700
# 250   182570
#
# [251 rows x 7 columns]
